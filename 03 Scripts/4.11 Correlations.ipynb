# %% [markdown]
# # Exploring relationships

# %% [markdown]
# ## Contents:
#
# #### 1. Importing Libraries and Data
# #### 2. Exploring Relationships
# ##### Correlations: Table, Matplot, Seaborn

# %% [markdown]
# ## 1.0 Importing Libraries and Data

# %% [markdown]
# ### 1.1 Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# %matplotlib inline

# %%
# Define path
path = r'C:\Users\Owner\Documents\Career Foundry\Instacart Basket Analysis'

# %%
# Import data
df = pd.read_pickle(os.path.join(path, '02 Data', '02 02 Prepared Data', 'final.pkl'))

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  num_dependants  fam_status  income _merge region  \
# ...

# %%
df.dtypes
# Out:
# order_id                     int64
# user_id                      int64
# order_number                 int64
# order_day_of_week            int64
# order_hour_of_day            int64
# days_since_prior_order     float64
# product_id                   int64
# add_to_cart_order            int64
# reordered                    int64
# product_name                object
# aisle_id                     int64
# department_id                int64
# prices                     float64
# price_range                 object
# busiest_day                 object
# grouped_days                object
# busiest_period_of_day       object
# max_orders                   int64
# loyalty_flag                object
# mean_price                 float64
# spending_flag               object
# median_days_since          float64
# frequency_flag              object
# gender                      object
# state                       object
# age                          int64
# date_joined                 object
# ...

# %% [markdown]
# ## 2.0 Exploring Relationships

# %% [markdown]
# ### 2.1 Create Subset

# %%
# Create subset of only numberical fields
sub = df[['order_day_of_week', 'order_hour_of_day', 'days_since_prior_order', 'product_id', 
          'add_to_cart_order', 'reordered', 'aisle_id', 'department_id', 'prices', 'max_orders',
         'mean_price', 'median_days_since', 'age', 'num_dependants', 'income']]

# %%
sub.shape
# Out:
# (32404859, 15)

# %% [markdown]
# ### 2.2 Correlations

# %% [markdown]
# #### Correlation table using pandas

# %%
# Create a correlation matrix using subset

sub.corr()
# Out:
#                         order_day_of_week  order_hour_of_day  \
# order_day_of_week                1.000000           0.012168
# order_hour_of_day                0.012168           1.000000
# days_since_prior_order          -0.030004           0.003872
# product_id                      -0.002397           0.000875
# add_to_cart_order               -0.009072          -0.014811
# reordered                       -0.006944          -0.023287
# aisle_id                        -0.001981          -0.001116
# department_id                    0.004426          -0.008859
# prices                          -0.000717           0.002222
# max_orders                       0.019595          -0.044265
# mean_price                       0.002691          -0.001036
# median_days_since               -0.021703           0.038725
# age                              0.002139           0.001874
# num_dependants                  -0.000481           0.000870
# ...

# %% [markdown]
# #### Correlation heatmap using matplot

# %%
# Matplot Correlation Heatmap

matcorf = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(sub.corr(), fignum=matcorf.number) # type of plot
plt.xticks(range(sub.shape[1]), sub.columns, fontsize=14, rotation=90) # x axis labels
plt.yticks(range(sub.shape[1]), sub.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# Save image
matcorf.figure.savefig(os.path.join(path, '04 Analysis', '04 03 Visualizations', 'mat_cor_heatmap.png'))

# %% [markdown]
# #### Correlation heatmap using seaborn

# %%
# Create a subplot with matplotlib
seacorf,ax = plt.subplots(figsize=(15,15))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above
corr = sns.heatmap(sub.corr(), annot = True, ax = ax, fmt = '.3f')

# %% [markdown]
# #### Top correlations (desc):
#         median_days_since/days_since_prior_order = 0.632
#         median_days_since/max_orders = -0.628
#         max_orders/days_since_prior_order = -0.487
#         income/age = 0.417

# %%
# Save seaborn correlation matrix
seacorf.figure.savefig(os.path.join(path, '04 Analysis', '04 03 Visualizations', 'sea_cor_heatmap.png'))

# %% [markdown]
# #### 2.2 Pair Plots

# %%
# Create subset of greatest correlation variables
sub_2 = df[['median_days_since', 'days_since_prior_order', 'max_orders','mean_price', 'income', 'age', 'reordered']]

# %%
#Create random assignments for each record
np.random.seed(4)
dev = np.random.rand(len(sub_2)) <= 0.9

# %%
#Separate samples into buckets
big = sub_2[dev]
small = sub_2[~dev]

# %%
#Reducing data frame to only information that is needed
sub_sample = small

# %%
# Create pair plot 
seapairplot = sns.pairplot(sub_sample)

# %%
# Save seaborn correlation matrix
seapairplot.figure.savefig(os.path.join(path, '04 Analysis', '04 03 Visualizations', 'sea_pairplot.png'))
